# %%
from IPython.display import Image

# %% [markdown]
# # 1 로봇을 SW입장에서 만들어 볼까요

# %% [markdown]
# ## 1.1 작은 로봇을 만들어 보자

# %%
Image('./ros1.png')

# %% [markdown]
# - 사람이 주변에 없을때 알아서 그 공간 곳곳을 열심히 탐색하는 로봇이 있는데
# - 주변에 사람이 지나가면 그 사람을 향해
# - 온도 센서를 접근시키고 온도를 측정

# %% [markdown]
# ## 1.2 아두이노로 해본다면? 잠시 상상해보자

# %%
Image('./ros2.png')

# %% [markdown]
# - 로봇이 주행을 한다 → 사람을 만난다. → 로봇팔을 동작시킨다
# - 어떤 순서로 코드를 작성해야하지????

# %% [markdown]
# ## 1.3 여러가지 상황에 맞게 대응하려면 역시 OS가 필요하다.

# %%
Image('./ros3.png')

# %% [markdown]
# - 멀티 태스크관리, 다양한 센서나 구동체의 관리 등에 OS가 필요하다
# - 그런데 그것만으로는 조금 힘들다.
# - 각 센서와 구동체의 데이터를 어떻게 연결하지?
# - 참고 동영상 : https://www.youtube.com/watch?v=-XRFe0nupM8

# %% [markdown]
# ## 1.4 또 다른 이유. 로봇은 혼자 하기 힘들다.

# %%
Image('./ros4.png')

# %% [markdown]
# - 내가 집중하고 싶은 것에 집중하기 위해 다른 부분은 누가 좀 도와주면 좋겠다.ㅠㅠ. (재활용성)

# %% [markdown]
# # 2 Robot Operating System

# %% [markdown]
# ## 2.1 ROS는 2000년 그 유명한 앤드류응 교수의 랩에서 시작했다

# %%
Image('./ros5.png')

# %% [markdown]
# ## 2.2 ROS의 구성

# %%
Image('./ros6.png')

# %% [markdown]
# ## 2.3 주행로봇에서의 Node와 Topic의 예

# %%
Image('./ros7.png')

# %% [markdown]
# ## 2.4 ROS는 System Architecture에 대한 부담을 덜어준다

# %%
Image('./ros8.png')

# %% [markdown]
# ## 2.5 RViz

# %%
Image('./ros9.png')

# %% [markdown]
# ## 2.6 Inverse Kinematics

# %%
Image('./ros10.png')

# %% [markdown]
# ## 2.7 물리엔진이 탑재된 Gazebo

# %%
Image('./ros11.png')

# %% [markdown]
# ## 2.8 이 모든 기능이 나를 위해 존재한다
